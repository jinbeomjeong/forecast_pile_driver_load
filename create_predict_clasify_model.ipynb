# %%
import datetime
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt

from utils.Dataset import load_logging_data
from utils.assemble_model import build_predict_model
from utils.layer import FeatureWiseScalingLayer, DecompositionLayer
from utils.miscellaneous import create_seq_dataset_multiple_input_single_output
from tensorflow import keras
from tqdm.notebook import tqdm
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)

# %%
train_data = load_logging_data(data_root_path='data/train')
val_data = load_logging_data(data_root_path='data/val')
# Out:
# Loading data...:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading data...:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
train_data['Data_Type'] = 'train'
val_data['Data_Type'] = 'validation'

dataset = pd.concat([train_data, val_data], axis=0)
dataset.reset_index(drop=True, inplace=True)

# %%
dataset
# Out:
#        Time  1 - default sample rate  BUMA 1_1 CH=4  BUMA 1_2 CH=5  \
# 0                           0.000000         -3.678        -4.9400
# 1                           0.100000         -2.509        -3.6970
# 2                           0.200000         -2.692        -3.5390
# 3                           0.300000         -3.185        -4.0320
# 4                           0.400000         -2.455        -3.5990
# ...                              ...            ...            ...
# 21369                     275.800013          5.423         0.6258
# 21370                     275.900013          5.708         0.8296
# 21371                     276.000013          6.429         1.1600
# 21372                     276.100013          6.606         1.8340
# 21373                     276.200013          7.521         2.8590
#
#        BUMA 1_3 CH=6  BUMA 2_1 CH=7  BUMA 2_2 CH=8  BUMA 2_3 CH=9  \
# 0             -3.767        -1.9070       -0.08352        0.04852
# 1             -2.093        -0.9704        0.48000        1.33100
# 2             -2.516        -0.9318        0.96660        0.97150
# 3             -2.501        -0.8281        0.19600        1.03300
# 4             -2.156        -0.8226        0.83630        0.98580
# ...              ...            ...            ...            ...
# 21369          5.743         0.3088       -2.86600       -7.25400
# 21370          6.097         1.1680       -2.38400       -6.72400
# 21371          6.845         1.1230       -2.06600       -6.96500
# 21372          7.174         0.7554       -1.82100       -6.24600
# 21373          7.480         1.9150       -1.85100       -5.84900
#
#        BUMA 3_1 CH=10  BUMA 3_2 CH=11  BUMA 3_3 CH=12  ...  \
# 0             -1.8750         -0.7639        -0.49290  ...
# 1             -1.2170         -0.1403        -0.09153  ...
# 2             -1.6220         -0.4432         0.09483  ...
# 3             -1.3780         -0.5022        -0.01985  ...
# 4             -1.3250         -0.5913        -0.07498  ...
# ...               ...             ...             ...  ...
# 21369         -1.0110          3.2680        -2.92500  ...
# 21370         -0.6484          3.1610        -3.02300  ...
# 21371         -0.1797          3.6360        -2.63700  ...
# 21372         -0.2944          3.9150        -2.03300  ...
# 21373          0.6076          4.1160        -1.80700  ...
#
#        MX840B_CH 2 CH=151  MX840B_CH 3 CH=152  MX840B_CH 4 CH=153  \
# 0              -1000000.0          -1000000.0          -1000000.0
# 1              -1000000.0          -1000000.0          -1000000.0
# 2              -1000000.0          -1000000.0          -1000000.0
# 3              -1000000.0          -1000000.0          -1000000.0
# 4              -1000000.0          -1000000.0          -1000000.0
# ...                   ...                 ...                 ...
# 21369          -1000000.0          -1000000.0          -1000000.0
# 21370          -1000000.0          -1000000.0          -1000000.0
# 21371          -1000000.0          -1000000.0          -1000000.0
# 21372          -1000000.0          -1000000.0          -1000000.0
# 21373          -1000000.0          -1000000.0          -1000000.0
#
#        MX840B_CH 5 CH=154  MX840B_CH 6 CH=155  MX840B_CH 7 CH=156  \
# 0              -1000000.0          -1000000.0          -1000000.0
# 1              -1000000.0          -1000000.0          -1000000.0
# 2              -1000000.0          -1000000.0          -1000000.0
# 3              -1000000.0          -1000000.0          -1000000.0
# 4              -1000000.0          -1000000.0          -1000000.0
# ...                   ...                 ...                 ...
# 21369          -1000000.0          -1000000.0          -1000000.0
# 21370          -1000000.0          -1000000.0          -1000000.0
# 21371          -1000000.0          -1000000.0          -1000000.0
# 21372          -1000000.0          -1000000.0          -1000000.0
# 21373          -1000000.0          -1000000.0          -1000000.0
#
#        MX840B_CH 8 CH=157\n  Work_Mode  Diff_Time(sec)   Data_Type
# 0                -1000000.0    pile_in             0.0       train
# 1                -1000000.0    pile_in             0.1       train
# 2                -1000000.0    pile_in             0.1       train
# 3                -1000000.0    pile_in             0.1       train
# 4                -1000000.0    pile_in             0.1       train
# ...                     ...        ...             ...         ...
# 21369            -1000000.0   pile_out             0.1  validation
# 21370            -1000000.0   pile_out             0.1  validation
# 21371            -1000000.0   pile_out             0.1  validation
# 21372            -1000000.0   pile_out             0.1  validation
# 21373            -1000000.0   pile_out             0.1  validation
#
# [21374 rows x 39 columns]

# %%
angle_name_list = list(dataset.columns)[22:24] + list(dataset.columns)[26:28]
print(angle_name_list)

pressure_name_list = list(dataset.columns)[18:20] + list(dataset.columns)[24:26]
print(pressure_name_list)

new_angle_name_list = ['Mast_X(deg)', 'Mast_Y(deg)', 'Base_X(deg)', 'Base_Y(deg)']
new_pressure_name_list = ['P1(bar)', 'P2(bar)', 'P3(bar)', 'P4(bar)']

dataset.rename(columns={'Time  1 - default sample rate': 'Time(sec)'}, inplace=True)
dataset.rename(columns={'caloutput_drill_depth CH=26': 'Drill_Depth(m)'}, inplace=True)
dataset.rename(columns={'caloutput_rotate_velocity CH=25': 'Drill_Rotation(RPM)'}, inplace=True)

for angle_name, new_angle_name in zip(angle_name_list, new_angle_name_list):
    dataset.rename(columns={angle_name: new_angle_name}, inplace=True)

for pressure_name, new_pressure_name in zip(pressure_name_list, new_pressure_name_list):
    dataset.rename(columns={pressure_name: new_pressure_name}, inplace=True)

dataset['Work_Load'] = (dataset[new_pressure_name_list[0]] * (dataset['Drill_Rotation(RPM)']))
dataset['Drill_Depth(m)'] = dataset['Drill_Depth(m)']/10

dataset
# Out:
# ['angle_Mast_X CH=27', 'angle_Mast_Y CH=28', 'angle_base_X CH=31', 'angle_base_Y CH=32']
# ['pressure_1_pressure_transmitter_1_drive1 CH=23', 'pressure_1_pressure_transmitter_2_drive2 CH=24', 'pressure_2_pressure_transmitter_6_cyl_1 CH=29', 'pressure_3_pressure_transmitter_7_cyl_2 CH=30']
#         Time(sec)  BUMA 1_1 CH=4  BUMA 1_2 CH=5  BUMA 1_3 CH=6  BUMA 2_1 CH=7  \
# 0        0.000000         -3.678        -4.9400         -3.767        -1.9070
# 1        0.100000         -2.509        -3.6970         -2.093        -0.9704
# 2        0.200000         -2.692        -3.5390         -2.516        -0.9318
# 3        0.300000         -3.185        -4.0320         -2.501        -0.8281
# 4        0.400000         -2.455        -3.5990         -2.156        -0.8226
# ...           ...            ...            ...            ...            ...
# 21369  275.800013          5.423         0.6258          5.743         0.3088
# 21370  275.900013          5.708         0.8296          6.097         1.1680
# 21371  276.000013          6.429         1.1600          6.845         1.1230
# 21372  276.100013          6.606         1.8340          7.174         0.7554
# 21373  276.200013          7.521         2.8590          7.480         1.9150
#
#        BUMA 2_2 CH=8  BUMA 2_3 CH=9  BUMA 3_1 CH=10  BUMA 3_2 CH=11  \
# 0           -0.08352        0.04852         -1.8750         -0.7639
# 1            0.48000        1.33100         -1.2170         -0.1403
# 2            0.96660        0.97150         -1.6220         -0.4432
# 3            0.19600        1.03300         -1.3780         -0.5022
# 4            0.83630        0.98580         -1.3250         -0.5913
# ...              ...            ...             ...             ...
# 21369       -2.86600       -7.25400         -1.0110          3.2680
# 21370       -2.38400       -6.72400         -0.6484          3.1610
# 21371       -2.06600       -6.96500         -0.1797          3.6360
# 21372       -1.82100       -6.24600         -0.2944          3.9150
# 21373       -1.85100       -5.84900          0.6076          4.1160
#
#        BUMA 3_3 CH=12  ...  MX840B_CH 3 CH=152  MX840B_CH 4 CH=153  \
# 0            -0.49290  ...          -1000000.0          -1000000.0
# 1            -0.09153  ...          -1000000.0          -1000000.0
# 2             0.09483  ...          -1000000.0          -1000000.0
# 3            -0.01985  ...          -1000000.0          -1000000.0
# 4            -0.07498  ...          -1000000.0          -1000000.0
# ...               ...  ...                 ...                 ...
# 21369        -2.92500  ...          -1000000.0          -1000000.0
# 21370        -3.02300  ...          -1000000.0          -1000000.0
# 21371        -2.63700  ...          -1000000.0          -1000000.0
# 21372        -2.03300  ...          -1000000.0          -1000000.0
# 21373        -1.80700  ...          -1000000.0          -1000000.0
#
#        MX840B_CH 5 CH=154  MX840B_CH 6 CH=155  MX840B_CH 7 CH=156  \
# 0              -1000000.0          -1000000.0          -1000000.0
# 1              -1000000.0          -1000000.0          -1000000.0
# 2              -1000000.0          -1000000.0          -1000000.0
# 3              -1000000.0          -1000000.0          -1000000.0
# 4              -1000000.0          -1000000.0          -1000000.0
# ...                   ...                 ...                 ...
# 21369          -1000000.0          -1000000.0          -1000000.0
# 21370          -1000000.0          -1000000.0          -1000000.0
# 21371          -1000000.0          -1000000.0          -1000000.0
# 21372          -1000000.0          -1000000.0          -1000000.0
# 21373          -1000000.0          -1000000.0          -1000000.0
#
#        MX840B_CH 8 CH=157\n  Work_Mode  Diff_Time(sec)   Data_Type  Work_Load
# 0                -1000000.0    pile_in             0.0       train        0.0
# 1                -1000000.0    pile_in             0.1       train        0.0
# 2                -1000000.0    pile_in             0.1       train        0.0
# 3                -1000000.0    pile_in             0.1       train        0.0
# 4                -1000000.0    pile_in             0.1       train        0.0
# ...                     ...        ...             ...         ...        ...
# 21369            -1000000.0   pile_out             0.1  validation        0.0
# 21370            -1000000.0   pile_out             0.1  validation        0.0
# 21371            -1000000.0   pile_out             0.1  validation        0.0
# 21372            -1000000.0   pile_out             0.1  validation        0.0
# 21373            -1000000.0   pile_out             0.1  validation        0.0
#
# [21374 rows x 40 columns]

# %%
for angle_name in new_angle_name_list:
    dataset[angle_name] = dataset[angle_name].clip(lower=-3, upper=3)

feature_name_list = new_angle_name_list + [new_pressure_name_list[0], new_pressure_name_list[1]]

target = np.abs(np.diff(dataset[new_angle_name_list[3]]))
target = target >= 0.3
target = np.concatenate([np.zeros(1), target])

feature_arr = dataset[feature_name_list].to_numpy()
dataset_arr = np.concatenate([feature_arr, target.reshape(-1, 1)], axis=1)
print(dataset_arr.shape)
# Out:
# (21374, 7)

# %%
n_samples = 2000
max_len = 250

random_start_idx = np.random.randint(low=0, high=dataset_arr.shape[0]-max_len*2, size=n_samples)
random_len_idx = np.random.randint(low=max_len*1, high=max_len*2, size=n_samples)

augment_train_dataset_arr = np.empty(shape=(0, dataset_arr.shape[1]))

for i, j in zip(tqdm(random_start_idx), random_len_idx):
    augment_train_dataset_arr = np.concatenate([augment_train_dataset_arr, dataset_arr[i:i+j, :]], axis=0)

print(augment_train_dataset_arr.shape)
print((augment_train_dataset_arr.itemsize * augment_train_dataset_arr.size)/(1024**2))
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# (746672, 7)
# 39.8765869140625

# %%
seq_len = 50
pred_distance = 25

train_feature, train_target = create_seq_dataset_multiple_input_single_output(data=augment_train_dataset_arr,
                                                                              seq_len=seq_len,
                                                                              pred_distance=pred_distance,
                                                                              target_idx_pos=augment_train_dataset_arr.shape[1]-1)
train_target = np.squeeze(train_target)
print(train_feature.shape, train_target.shape)

print((train_feature.itemsize*train_feature.size)/(1024**2))
print((train_target.itemsize*train_target.size)/(1024**2))
# Out:
# creating sequence dataset...:   0%|          | 0/746647 [00:00<?, ?it/s]
# (746598, 50, 6) (746598,)
# 1708.8272094726562
# 5.6960906982421875

# %%
val_feature, val_target = create_seq_dataset_multiple_input_single_output(data=dataset_arr,
                                                                          seq_len=seq_len,
                                                                          pred_distance=pred_distance,
                                                                          target_idx_pos=dataset_arr.shape[1]-1)
val_target = np.squeeze(val_target)
print(val_feature.shape, val_target.shape)

print((val_feature.itemsize*val_feature.size)/(1024**2))
print((val_target.itemsize*val_target.size)/(1024**2))
# Out:
# creating sequence dataset...:   0%|          | 0/21349 [00:00<?, ?it/s]
# (21300, 50, 6) (21300,)
# 48.7518310546875
# 0.162506103515625

# %%
model = build_predict_model(input_shape=(train_feature.shape[1:]), d_dims=64, dropout_rate=0.5, learning_rate=0.001)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 50, 6)]      0           []
#
#  tf.__operators__.getitem (Slic  (None, 50, 4)       0           ['input_1[0][0]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (None, 50, 2)       0           ['input_1[0][0]']
#  icingOpLambda)
#
#  batch_normalization (BatchNorm  (None, 50, 4)       16          ['tf.__operators__.getitem[0][0]'
#  alization)                                                      ]
#
#  batch_normalization_1 (BatchNo  (None, 50, 2)       8           ['tf.__operators__.getitem_1[0][0
#  rmalization)                                                    ]']
#
#  concatenate (Concatenate)      (None, 50, 6)        0           ['batch_normalization[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  dense (Dense)                  (None, 50, 64)       448         ['concatenate[0][0]']
#
#  conv1d (Conv1D)                (None, 50, 64)       12352       ['dense[0][0]']
#
#  dropout (Dropout)              (None, 50, 64)       0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 50, 64)       12352       ['dropout[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 50, 64)      0           ['conv1d_1[0][0]',
#  da)                                                              'dense[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 50, 64)      256         ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  activation (Activation)        (None, 50, 64)       0           ['batch_normalization_2[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 50, 64)       12352       ['activation[0][0]']
#
#  dropout_1 (Dropout)            (None, 50, 64)       0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 50, 64)       12352       ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 50, 64)      0           ['conv1d_3[0][0]',
#  mbda)                                                            'activation[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 50, 64)      256         ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 50, 64)       0           ['batch_normalization_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 50, 64)       12352       ['activation_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 50, 64)       0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 50, 64)       12352       ['dropout_2[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 50, 64)      0           ['conv1d_5[0][0]',
#  mbda)                                                            'activation_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 50, 64)      256         ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 50, 64)       0           ['batch_normalization_4[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 50, 64)       12352       ['activation_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 50, 64)       0           ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 50, 64)       12352       ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 50, 64)      0           ['conv1d_7[0][0]',
#  mbda)                                                            'activation_2[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 50, 64)      256         ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 50, 64)       0           ['batch_normalization_5[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 50, 64)       12352       ['activation_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 50, 64)       0           ['conv1d_8[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 50, 64)       12352       ['dropout_4[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 50, 64)      0           ['conv1d_9[0][0]',
#  mbda)                                                            'activation_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 50, 64)      256         ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 50, 64)       0           ['batch_normalization_6[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 50, 64)       12352       ['activation_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 50, 64)       0           ['conv1d_10[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 50, 64)       12352       ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 50, 64)      0           ['conv1d_11[0][0]',
#  mbda)                                                            'activation_4[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 50, 64)      256         ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 50, 64)       0           ['batch_normalization_7[0][0]']
#
#  flatten (Flatten)              (None, 3200)         0           ['activation_5[0][0]']
#
#  dropout_6 (Dropout)            (None, 3200)         0           ['flatten[0][0]']
#
#  feature_wise_scaling_layer (Fe  (None, 3200)        3200        ['dropout_6[0][0]']
#  atureWiseScalingLayer)
#
#  dense_1 (Dense)                (None, 150)          480150      ['feature_wise_scaling_layer[0][0
#                                                                  ]']
#
#  layer_normalization (LayerNorm  (None, 150)         300         ['dense_1[0][0]']
#  alization)
#
#  tf.expand_dims (TFOpLambda)    (None, 150, 1)       0           ['layer_normalization[0][0]']
#
#  average_pooling1d_5 (AveragePo  (None, 12, 1)       0           ['tf.expand_dims[0][0]']
#  oling1D)
#
#  decomposition_layer (Decomposi  ((None, 150, 1),    0           ['tf.expand_dims[0][0]']
#  tionLayer)                      (None, 150, 1))
#
#  decomposition_layer_6 (Decompo  ((None, 12, 1),     0           ['average_pooling1d_5[0][0]']
#  sitionLayer)                    (None, 12, 1))
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 150)         0           ['decomposition_layer[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_13 (TFOpL  (None, 12)          0           ['decomposition_layer_6[0][1]']
#  ambda)
#
#  dense_2 (Dense)                (None, 150)          22650       ['tf.compat.v1.squeeze[0][0]']
#
#  dense_15 (Dense)               (None, 12)           156         ['tf.compat.v1.squeeze_13[0][0]']
#
#  dropout_7 (Dropout)            (None, 150)          0           ['dense_2[0][0]']
#
#  dropout_20 (Dropout)           (None, 12)           0           ['dense_15[0][0]']
#
#  average_pooling1d_4 (AveragePo  (None, 15, 1)       0           ['tf.expand_dims[0][0]']
#  oling1D)
#
#  average_pooling1d (AveragePool  (None, 75, 1)       0           ['tf.expand_dims[0][0]']
#  ing1D)
#
#  dense_22 (Dense)               (None, 15)           195         ['dropout_20[0][0]']
#
#  decomposition_layer_5 (Decompo  ((None, 15, 1),     0           ['average_pooling1d_4[0][0]']
#  sitionLayer)                    (None, 15, 1))
#
#  decomposition_layer_1 (Decompo  ((None, 75, 1),     0           ['average_pooling1d[0][0]']
#  sitionLayer)                    (None, 75, 1))
#
#  dense_16 (Dense)               (None, 75)           11325       ['dropout_7[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 15)          30          ['dense_22[0][0]']
#  rmalization)
#
#  tf.compat.v1.squeeze_11 (TFOpL  (None, 15)          0           ['decomposition_layer_5[0][1]']
#  ambda)
#
#  layer_normalization_1 (LayerNo  (None, 75)          150         ['dense_16[0][0]']
#  rmalization)
#
#  tf.compat.v1.squeeze_2 (TFOpLa  (None, 75)          0           ['decomposition_layer_1[0][0]']
#  mbda)
#
#  dropout_27 (Dropout)           (None, 15)           0           ['layer_normalization_7[0][0]']
#
#  dense_13 (Dense)               (None, 15)           240         ['tf.compat.v1.squeeze_11[0][0]']
#
#  dropout_21 (Dropout)           (None, 75)           0           ['layer_normalization_1[0][0]']
#
#  dense_4 (Dense)                (None, 75)           5700        ['tf.compat.v1.squeeze_2[0][0]']
#
#  activation_13 (Activation)     (None, 15)           0           ['dropout_27[0][0]']
#
#  dropout_18 (Dropout)           (None, 15)           0           ['dense_13[0][0]']
#
#  activation_7 (Activation)      (None, 75)           0           ['dropout_21[0][0]']
#
#  dropout_9 (Dropout)            (None, 75)           0           ['dense_4[0][0]']
#
#  add_6 (Add)                    (None, 15)           0           ['activation_13[0][0]',
#                                                                   'dropout_18[0][0]']
#
#  average_pooling1d_3 (AveragePo  (None, 18, 1)       0           ['tf.expand_dims[0][0]']
#  oling1D)
#
#  average_pooling1d_1 (AveragePo  (None, 37, 1)       0           ['tf.expand_dims[0][0]']
#  oling1D)
#
#  add (Add)                      (None, 75)           0           ['activation_7[0][0]',
#                                                                   'dropout_9[0][0]']
#
#  dense_23 (Dense)               (None, 18)           288         ['add_6[0][0]']
#
#  decomposition_layer_4 (Decompo  ((None, 18, 1),     0           ['average_pooling1d_3[0][0]']
#  sitionLayer)                    (None, 18, 1))
#
#  decomposition_layer_2 (Decompo  ((None, 37, 1),     0           ['average_pooling1d_1[0][0]']
#  sitionLayer)                    (None, 37, 1))
#
#  dense_17 (Dense)               (None, 37)           2812        ['add[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 18)          36          ['dense_23[0][0]']
#  rmalization)
#
#  tf.compat.v1.squeeze_9 (TFOpLa  (None, 18)          0           ['decomposition_layer_4[0][1]']
#  mbda)
#
#  layer_normalization_2 (LayerNo  (None, 37)          74          ['dense_17[0][0]']
#  rmalization)
#
#  tf.compat.v1.squeeze_4 (TFOpLa  (None, 37)          0           ['decomposition_layer_2[0][0]']
#  mbda)
#
#  dropout_28 (Dropout)           (None, 18)           0           ['layer_normalization_8[0][0]']
#
#  dense_11 (Dense)               (None, 18)           342         ['tf.compat.v1.squeeze_9[0][0]']
#
#  dropout_22 (Dropout)           (None, 37)           0           ['layer_normalization_2[0][0]']
#
#  dense_6 (Dense)                (None, 37)           1406        ['tf.compat.v1.squeeze_4[0][0]']
#
#  activation_14 (Activation)     (None, 18)           0           ['dropout_28[0][0]']
#
#  dropout_16 (Dropout)           (None, 18)           0           ['dense_11[0][0]']
#
#  activation_8 (Activation)      (None, 37)           0           ['dropout_22[0][0]']
#
#  dropout_11 (Dropout)           (None, 37)           0           ['dense_6[0][0]']
#
#  add_7 (Add)                    (None, 18)           0           ['activation_14[0][0]',
#                                                                   'dropout_16[0][0]']
#
#  average_pooling1d_2 (AveragePo  (None, 25, 1)       0           ['tf.expand_dims[0][0]']
#  oling1D)
#
#  add_1 (Add)                    (None, 37)           0           ['activation_8[0][0]',
#                                                                   'dropout_11[0][0]']
#
#  dense_24 (Dense)               (None, 25)           475         ['add_7[0][0]']
#
#  decomposition_layer_3 (Decompo  ((None, 25, 1),     0           ['average_pooling1d_2[0][0]']
#  sitionLayer)                    (None, 25, 1))
#
#  dense_18 (Dense)               (None, 25)           950         ['add_1[0][0]']
#
#  layer_normalization_9 (LayerNo  (None, 25)          50          ['dense_24[0][0]']
#  rmalization)
#
#  tf.compat.v1.squeeze_7 (TFOpLa  (None, 25)          0           ['decomposition_layer_3[0][1]']
#  mbda)
#
#  layer_normalization_3 (LayerNo  (None, 25)          50          ['dense_18[0][0]']
#  rmalization)
#
#  tf.compat.v1.squeeze_6 (TFOpLa  (None, 25)          0           ['decomposition_layer_3[0][0]']
#  mbda)
#
#  dropout_29 (Dropout)           (None, 25)           0           ['layer_normalization_9[0][0]']
#
#  dense_9 (Dense)                (None, 25)           650         ['tf.compat.v1.squeeze_7[0][0]']
#
#  dropout_23 (Dropout)           (None, 25)           0           ['layer_normalization_3[0][0]']
#
#  dense_8 (Dense)                (None, 25)           650         ['tf.compat.v1.squeeze_6[0][0]']
#
#  activation_15 (Activation)     (None, 25)           0           ['dropout_29[0][0]']
#
#  dropout_14 (Dropout)           (None, 25)           0           ['dense_9[0][0]']
#
#  activation_9 (Activation)      (None, 25)           0           ['dropout_23[0][0]']
#
#  dropout_13 (Dropout)           (None, 25)           0           ['dense_8[0][0]']
#
#  add_8 (Add)                    (None, 25)           0           ['activation_15[0][0]',
#                                                                   'dropout_14[0][0]']
#
#  add_2 (Add)                    (None, 25)           0           ['activation_9[0][0]',
#                                                                   'dropout_13[0][0]']
#
#  dense_25 (Dense)               (None, 37)           962         ['add_8[0][0]']
#
#  dense_19 (Dense)               (None, 18)           468         ['add_2[0][0]']
#
#  layer_normalization_10 (LayerN  (None, 37)          74          ['dense_25[0][0]']
#  ormalization)
#
#  tf.compat.v1.squeeze_5 (TFOpLa  (None, 37)          0           ['decomposition_layer_2[0][1]']
#  mbda)
#
#  layer_normalization_4 (LayerNo  (None, 18)          36          ['dense_19[0][0]']
#  rmalization)
#
#  tf.compat.v1.squeeze_8 (TFOpLa  (None, 18)          0           ['decomposition_layer_4[0][0]']
#  mbda)
#
#  dropout_30 (Dropout)           (None, 37)           0           ['layer_normalization_10[0][0]']
#
#  dense_7 (Dense)                (None, 37)           1406        ['tf.compat.v1.squeeze_5[0][0]']
#
#  dropout_24 (Dropout)           (None, 18)           0           ['layer_normalization_4[0][0]']
#
#  dense_10 (Dense)               (None, 18)           342         ['tf.compat.v1.squeeze_8[0][0]']
#
#  activation_16 (Activation)     (None, 37)           0           ['dropout_30[0][0]']
#
#  dropout_12 (Dropout)           (None, 37)           0           ['dense_7[0][0]']
#
#  activation_10 (Activation)     (None, 18)           0           ['dropout_24[0][0]']
#
#  dropout_15 (Dropout)           (None, 18)           0           ['dense_10[0][0]']
#
#  add_9 (Add)                    (None, 37)           0           ['activation_16[0][0]',
#                                                                   'dropout_12[0][0]']
#
#  add_3 (Add)                    (None, 18)           0           ['activation_10[0][0]',
#                                                                   'dropout_15[0][0]']
#
#  dense_26 (Dense)               (None, 75)           2850        ['add_9[0][0]']
#
#  dense_20 (Dense)               (None, 15)           285         ['add_3[0][0]']
#
#  layer_normalization_11 (LayerN  (None, 75)          150         ['dense_26[0][0]']
#  ormalization)
#
#  tf.compat.v1.squeeze_3 (TFOpLa  (None, 75)          0           ['decomposition_layer_1[0][1]']
#  mbda)
#
#  layer_normalization_5 (LayerNo  (None, 15)          30          ['dense_20[0][0]']
#  rmalization)
#
#  tf.compat.v1.squeeze_10 (TFOpL  (None, 15)          0           ['decomposition_layer_5[0][0]']
#  ambda)
#
#  dropout_31 (Dropout)           (None, 75)           0           ['layer_normalization_11[0][0]']
#
#  dense_5 (Dense)                (None, 75)           5700        ['tf.compat.v1.squeeze_3[0][0]']
#
#  dropout_25 (Dropout)           (None, 15)           0           ['layer_normalization_5[0][0]']
#
#  dense_12 (Dense)               (None, 15)           240         ['tf.compat.v1.squeeze_10[0][0]']
#
#  activation_17 (Activation)     (None, 75)           0           ['dropout_31[0][0]']
#
#  dropout_10 (Dropout)           (None, 75)           0           ['dense_5[0][0]']
#
#  activation_11 (Activation)     (None, 15)           0           ['dropout_25[0][0]']
#
#  dropout_17 (Dropout)           (None, 15)           0           ['dense_12[0][0]']
#
#  add_10 (Add)                   (None, 75)           0           ['activation_17[0][0]',
#                                                                   'dropout_10[0][0]']
#
#  add_4 (Add)                    (None, 15)           0           ['activation_11[0][0]',
#                                                                   'dropout_17[0][0]']
#
#  dense_27 (Dense)               (None, 150)          11400       ['add_10[0][0]']
#
#  dense_21 (Dense)               (None, 12)           192         ['add_4[0][0]']
#
#  layer_normalization_12 (LayerN  (None, 150)         300         ['dense_27[0][0]']
#  ormalization)
#
#  tf.compat.v1.squeeze_1 (TFOpLa  (None, 150)         0           ['decomposition_layer[0][1]']
#  mbda)
#
#  layer_normalization_6 (LayerNo  (None, 12)          24          ['dense_21[0][0]']
#  rmalization)
#
#  tf.compat.v1.squeeze_12 (TFOpL  (None, 12)          0           ['decomposition_layer_6[0][0]']
#  ambda)
#
#  dropout_32 (Dropout)           (None, 150)          0           ['layer_normalization_12[0][0]']
#
#  dense_3 (Dense)                (None, 150)          22650       ['tf.compat.v1.squeeze_1[0][0]']
#
#  dropout_26 (Dropout)           (None, 12)           0           ['layer_normalization_6[0][0]']
#
#  dense_14 (Dense)               (None, 12)           156         ['tf.compat.v1.squeeze_12[0][0]']
#
#  activation_18 (Activation)     (None, 150)          0           ['dropout_32[0][0]']
#
#  dropout_8 (Dropout)            (None, 150)          0           ['dense_3[0][0]']
#
#  activation_12 (Activation)     (None, 12)           0           ['dropout_26[0][0]']
#
#  dropout_19 (Dropout)           (None, 12)           0           ['dense_14[0][0]']
#
#  add_11 (Add)                   (None, 150)          0           ['activation_18[0][0]',
#                                                                   'dropout_8[0][0]']
#
#  add_5 (Add)                    (None, 12)           0           ['activation_12[0][0]',
#                                                                   'dropout_19[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 150)         0           ['dropout_7[0][0]',
#  mbda)                                                            'add_11[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 75)          0           ['add[0][0]',
#  mbda)                                                            'add_10[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 37)          0           ['add_1[0][0]',
#  mbda)                                                            'add_9[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 25)          0           ['add_2[0][0]',
#  mbda)                                                            'add_8[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 18)          0           ['add_3[0][0]',
#  ambda)                                                           'add_7[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 15)          0           ['add_4[0][0]',
#  ambda)                                                           'add_6[0][0]']
#
#  tf.__operators__.add_12 (TFOpL  (None, 12)          0           ['add_5[0][0]',
#  ambda)                                                           'dropout_20[0][0]']
#
#  dense_28 (Dense)               (None, 128)          19328       ['tf.__operators__.add_6[0][0]']
#
#  dense_30 (Dense)               (None, 128)          9728        ['tf.__operators__.add_7[0][0]']
#
#  dense_32 (Dense)               (None, 128)          4864        ['tf.__operators__.add_8[0][0]']
#
#  dense_34 (Dense)               (None, 128)          3328        ['tf.__operators__.add_9[0][0]']
#
#  dense_36 (Dense)               (None, 128)          2432        ['tf.__operators__.add_10[0][0]']
#
#  dense_38 (Dense)               (None, 128)          2048        ['tf.__operators__.add_11[0][0]']
#
#  dense_40 (Dense)               (None, 128)          1664        ['tf.__operators__.add_12[0][0]']
#
#  layer_normalization_13 (LayerN  (None, 128)         256         ['dense_28[0][0]']
#  ormalization)
#
#  layer_normalization_14 (LayerN  (None, 128)         256         ['dense_30[0][0]']
#  ormalization)
#
#  layer_normalization_15 (LayerN  (None, 128)         256         ['dense_32[0][0]']
#  ormalization)
#
#  layer_normalization_16 (LayerN  (None, 128)         256         ['dense_34[0][0]']
#  ormalization)
#
#  layer_normalization_17 (LayerN  (None, 128)         256         ['dense_36[0][0]']
#  ormalization)
#
#  layer_normalization_18 (LayerN  (None, 128)         256         ['dense_38[0][0]']
#  ormalization)
#
#  layer_normalization_19 (LayerN  (None, 128)         256         ['dense_40[0][0]']
#  ormalization)
#
#  dropout_33 (Dropout)           (None, 128)          0           ['layer_normalization_13[0][0]']
#
#  dropout_34 (Dropout)           (None, 128)          0           ['layer_normalization_14[0][0]']
#
#  dropout_35 (Dropout)           (None, 128)          0           ['layer_normalization_15[0][0]']
#
#  dropout_36 (Dropout)           (None, 128)          0           ['layer_normalization_16[0][0]']
#
#  dropout_37 (Dropout)           (None, 128)          0           ['layer_normalization_17[0][0]']
#
#  dropout_38 (Dropout)           (None, 128)          0           ['layer_normalization_18[0][0]']
#
#  dropout_39 (Dropout)           (None, 128)          0           ['layer_normalization_19[0][0]']
#
#  dense_29 (Dense)               (None, 150)          19350       ['dropout_33[0][0]']
#
#  dense_31 (Dense)               (None, 150)          19350       ['dropout_34[0][0]']
#
#  dense_33 (Dense)               (None, 150)          19350       ['dropout_35[0][0]']
#
#  dense_35 (Dense)               (None, 150)          19350       ['dropout_36[0][0]']
#
#  dense_37 (Dense)               (None, 150)          19350       ['dropout_37[0][0]']
#
#  dense_39 (Dense)               (None, 150)          19350       ['dropout_38[0][0]']
#
# ...
#  dense_92 (Dense)               (None, 15)           240         ['tf.compat.v1.squeeze_38[0][0]']
#
#  activation_41 (Activation)     (None, 75)           0           ['dropout_97[0][0]']
#
#  dropout_76 (Dropout)           (None, 75)           0           ['dense_85[0][0]']
#
#  activation_35 (Activation)     (None, 15)           0           ['dropout_91[0][0]']
#
#  dropout_83 (Dropout)           (None, 15)           0           ['dense_92[0][0]']
#
#  add_36 (Add)                   (None, 75)           0           ['activation_41[0][0]',
#                                                                   'dropout_76[0][0]']
#
#  add_30 (Add)                   (None, 15)           0           ['activation_35[0][0]',
#                                                                   'dropout_83[0][0]']
#
#  dense_107 (Dense)              (None, 150)          11400       ['add_36[0][0]']
#
#  dense_101 (Dense)              (None, 12)           192         ['add_30[0][0]']
#
#  layer_normalization_50 (LayerN  (None, 150)         300         ['dense_107[0][0]']
#  ormalization)
#
#  tf.compat.v1.squeeze_29 (TFOpL  (None, 150)         0           ['decomposition_layer_14[0][1]']
#  ambda)
#
#  layer_normalization_44 (LayerN  (None, 12)          24          ['dense_101[0][0]']
#  ormalization)
#
#  tf.compat.v1.squeeze_40 (TFOpL  (None, 12)          0           ['decomposition_layer_20[0][0]']
#  ambda)
#
#  dropout_98 (Dropout)           (None, 150)          0           ['layer_normalization_50[0][0]']
#
#  dense_83 (Dense)               (None, 150)          22650       ['tf.compat.v1.squeeze_29[0][0]']
#
#  dropout_92 (Dropout)           (None, 12)           0           ['layer_normalization_44[0][0]']
#
#  dense_94 (Dense)               (None, 12)           156         ['tf.compat.v1.squeeze_40[0][0]']
#
#  activation_42 (Activation)     (None, 150)          0           ['dropout_98[0][0]']
#
#  dropout_74 (Dropout)           (None, 150)          0           ['dense_83[0][0]']
#
#  activation_36 (Activation)     (None, 12)           0           ['dropout_92[0][0]']
#
#  dropout_85 (Dropout)           (None, 12)           0           ['dense_94[0][0]']
#
#  add_37 (Add)                   (None, 150)          0           ['activation_42[0][0]',
#                                                                   'dropout_74[0][0]']
#
#  add_31 (Add)                   (None, 12)           0           ['activation_36[0][0]',
#                                                                   'dropout_85[0][0]']
#
#  tf.__operators__.add_22 (TFOpL  (None, 150)         0           ['dropout_73[0][0]',
#  ambda)                                                           'add_37[0][0]']
#
#  tf.__operators__.add_23 (TFOpL  (None, 75)          0           ['add_26[0][0]',
#  ambda)                                                           'add_36[0][0]']
#
#  tf.__operators__.add_24 (TFOpL  (None, 37)          0           ['add_27[0][0]',
#  ambda)                                                           'add_35[0][0]']
#
#  tf.__operators__.add_25 (TFOpL  (None, 25)          0           ['add_28[0][0]',
#  ambda)                                                           'add_34[0][0]']
#
#  tf.__operators__.add_26 (TFOpL  (None, 18)          0           ['add_29[0][0]',
#  ambda)                                                           'add_33[0][0]']
#
#  tf.__operators__.add_27 (TFOpL  (None, 15)          0           ['add_30[0][0]',
#  ambda)                                                           'add_32[0][0]']
#
#  tf.__operators__.add_28 (TFOpL  (None, 12)          0           ['add_31[0][0]',
#  ambda)                                                           'dropout_86[0][0]']
#
#  dense_108 (Dense)              (None, 128)          19328       ['tf.__operators__.add_22[0][0]']
#
#  dense_110 (Dense)              (None, 128)          9728        ['tf.__operators__.add_23[0][0]']
#
#  dense_112 (Dense)              (None, 128)          4864        ['tf.__operators__.add_24[0][0]']
#
#  dense_114 (Dense)              (None, 128)          3328        ['tf.__operators__.add_25[0][0]']
#
#  dense_116 (Dense)              (None, 128)          2432        ['tf.__operators__.add_26[0][0]']
#
#  dense_118 (Dense)              (None, 128)          2048        ['tf.__operators__.add_27[0][0]']
#
#  dense_120 (Dense)              (None, 128)          1664        ['tf.__operators__.add_28[0][0]']
#
#  layer_normalization_51 (LayerN  (None, 128)         256         ['dense_108[0][0]']
#  ormalization)
#
#  layer_normalization_52 (LayerN  (None, 128)         256         ['dense_110[0][0]']
#  ormalization)
#
#  layer_normalization_53 (LayerN  (None, 128)         256         ['dense_112[0][0]']
#  ormalization)
#
#  layer_normalization_54 (LayerN  (None, 128)         256         ['dense_114[0][0]']
#  ormalization)
#
#  layer_normalization_55 (LayerN  (None, 128)         256         ['dense_116[0][0]']
#  ormalization)
#
#  layer_normalization_56 (LayerN  (None, 128)         256         ['dense_118[0][0]']
#  ormalization)
#
#  layer_normalization_57 (LayerN  (None, 128)         256         ['dense_120[0][0]']
#  ormalization)
#
#  dropout_99 (Dropout)           (None, 128)          0           ['layer_normalization_51[0][0]']
#
#  dropout_100 (Dropout)          (None, 128)          0           ['layer_normalization_52[0][0]']
#
#  dropout_101 (Dropout)          (None, 128)          0           ['layer_normalization_53[0][0]']
#
#  dropout_102 (Dropout)          (None, 128)          0           ['layer_normalization_54[0][0]']
#
#  dropout_103 (Dropout)          (None, 128)          0           ['layer_normalization_55[0][0]']
#
#  dropout_104 (Dropout)          (None, 128)          0           ['layer_normalization_56[0][0]']
#
#  dropout_105 (Dropout)          (None, 128)          0           ['layer_normalization_57[0][0]']
#
#  dense_109 (Dense)              (None, 150)          19350       ['dropout_99[0][0]']
#
#  dense_111 (Dense)              (None, 150)          19350       ['dropout_100[0][0]']
#
#  dense_113 (Dense)              (None, 150)          19350       ['dropout_101[0][0]']
#
#  dense_115 (Dense)              (None, 150)          19350       ['dropout_102[0][0]']
#
#  dense_117 (Dense)              (None, 150)          19350       ['dropout_103[0][0]']
#
#  dense_119 (Dense)              (None, 150)          19350       ['dropout_104[0][0]']
#
#  dense_121 (Dense)              (None, 150)          19350       ['dropout_105[0][0]']
#
#  add_38 (Add)                   (None, 150)          0           ['dense_109[0][0]',
#                                                                   'dense_111[0][0]',
#                                                                   'dense_113[0][0]',
#                                                                   'dense_115[0][0]',
#                                                                   'dense_117[0][0]',
#                                                                   'dense_119[0][0]',
#                                                                   'dense_121[0][0]']
#
#  tf.__operators__.add_29 (TFOpL  (None, 150)         0           ['add_38[0][0]',
#  ambda)                                                           'tf.__operators__.add_21[0][0]']
#
#  layer_normalization_58 (LayerN  (None, 150)         300         ['tf.__operators__.add_29[0][0]']
#  ormalization)
#
#  feature_wise_scaling_layer_1 (  (None, 150)         150         ['layer_normalization_58[0][0]']
#  FeatureWiseScalingLayer)
#
#  dense_122 (Dense)              (None, 1)            151         ['feature_wise_scaling_layer_1[0]
#                                                                  [0]']
#
# ==================================================================================================
# Total params: 1,462,867
# Trainable params: 1,462,087
# Non-trainable params: 780
# __________________________________________________________________________________________________

# %%
#keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, show_layer_activations=True, show_dtype=True)

# %%
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=500, verbose=0)
csv_logger = keras.callbacks.CSVLogger(filename=f'log_{pred_distance}_model.csv', append=False, separator=',')
model_chk_point = keras.callbacks.ModelCheckpoint(filepath=f'model_{pred_distance}.keras', monitor="val_loss", verbose=2,
                                                  save_best_only=True, save_weights_only=False, mode="min", save_freq="epoch", initial_value_threshold=None)

log_dir = "logs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)


model.fit(x=train_feature, y=train_target, validation_data=(val_feature, val_target),
          epochs=999999, batch_size=5000, verbose=0, callbacks=[early_stop, csv_logger, model_chk_point, tensorboard_callback])
# Out:
# Epoch 1: val_loss improved from inf to 0.02113, saving model to model_25.keras
#
# Epoch 2: val_loss improved from 0.02113 to 0.01830, saving model to model_25.keras

# %%
model = keras.models.load_model(f'models/model_{pred_distance}.keras', custom_objects={'FeatureWiseScalingLayer': FeatureWiseScalingLayer,
                                                                                       'DecompositionLayer': DecompositionLayer})

# %%
val_pred = model.predict(val_feature, verbose=2)
val_pred = np.squeeze(val_pred)
# Out:
# 666/666 - 15s - 15s/epoch - 23ms/step

# %%
sns.set_theme(font_scale=1)
sns.set_style("whitegrid", {'grid.linestyle': '--'})

sns.lineplot(val_target, linewidth=3, label='Ground Truth', color='Green')
sns.lineplot(val_pred, linewidth=1, linestyle='--', label='Predicted', color='Red')

plt.xlim(0, 2000)
# Out:
# (0.0, 2000.0)
